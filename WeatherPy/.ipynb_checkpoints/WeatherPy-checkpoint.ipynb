# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 563

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather"



# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}?q={city}&appid={weather_api_key}&units=metric"

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

   # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        response = requests.get(city_url).json()

        # Check if the response contains the necessary data
        if response["cod"] != 200:
            print(f"City {city} not found. Skipping...")
            continue

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = response["coord"]["lat"]
        city_lng = response["coord"]["lon"]
        city_max_temp = response["main"]["temp_max"]
        city_humidity = response["main"]["humidity"]
        city_clouds = response["clouds"]["all"]
        city_wind = response["wind"]["speed"]
        city_country = response["sys"]["country"]
        city_date = response["dt"]


        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lompoc
# Processing Record 2 of Set 1 | fuvahmulah
# City fuvahmulah not found. Skipping...
# Processing Record 3 of Set 1 | gadzhiyevo
# Processing Record 4 of Set 1 | nikolayevsk-on-amure
# Processing Record 5 of Set 1 | bilibino
# Processing Record 6 of Set 1 | puerto leguizamo
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | port douglas
# Processing Record 9 of Set 1 | aral
# Processing Record 10 of Set 1 | alice springs
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | ghat
# Processing Record 13 of Set 1 | es castell
# Processing Record 14 of Set 1 | novofedorovka
# Processing Record 15 of Set 1 | port mathurin
# Processing Record 16 of Set 1 | port-aux-francais
# Processing Record 17 of Set 1 | saipan
# Processing Record 18 of Set 1 | preobrazheniye
# Processing Record 19 of Set 1 | chonchi
# Processing Record 20 of Set 1 | tiksi
# Processing Record 21 of Set 1 | port elizabeth
# Processing Record 22 of Set 1 | kuanda
# Processing Record 23 of Set 1 | hafar al-batin
# Processing Record 24 of Set 1 | nuriootpa
# Processing Record 25 of Set 1 | boende
# Processing Record 26 of Set 1 | waitangi
# Processing Record 27 of Set 1 | san rafael
# Processing Record 28 of Set 1 | port lincoln
# Processing Record 29 of Set 1 | general levalle
# Processing Record 30 of Set 1 | yellowknife
# Processing Record 31 of Set 1 | lebu
# Processing Record 32 of Set 1 | naze
# Processing Record 33 of Set 1 | albany
# Processing Record 34 of Set 1 | qaqortoq
# Processing Record 35 of Set 1 | bredasdorp
# Processing Record 36 of Set 1 | peterborough
# Processing Record 37 of Set 1 | ribeira grande
# Processing Record 38 of Set 1 | carlisle
# Processing Record 39 of Set 1 | toliara
# Processing Record 40 of Set 1 | invercargill
# Processing Record 41 of Set 1 | san andres
# Processing Record 42 of Set 1 | grytviken
# Processing Record 43 of Set 1 | udachny
# Processing Record 44 of Set 1 | longyearbyen
# Processing Record 45 of Set 1 | stanley
# Processing Record 46 of Set 1 | adamstown
# Processing Record 47 of Set 1 | puerto natales
# Processing Record 48 of Set 1 | rongelap
# Processing Record 49 of Set 1 | constantia
# Processing Record 50 of Set 1 | atafu village
# Processing Record 0 of Set 2 | papatowai
# Processing Record 1 of Set 2 | mount isa
# Processing Record 2 of Set 2 | iskateley
# Processing Record 3 of Set 2 | sarandi del yi
# Processing Record 4 of Set 2 | whyalla norrie
# City whyalla norrie not found. Skipping...
# Processing Record 5 of Set 2 | praia da vitoria
# Processing Record 6 of Set 2 | ust-nera
# Processing Record 7 of Set 2 | okhotsk
# Processing Record 8 of Set 2 | vila franca do campo
# Processing Record 9 of Set 2 | mlangali
# Processing Record 10 of Set 2 | brookings
# Processing Record 11 of Set 2 | port macquarie
# Processing Record 12 of Set 2 | revda
# Processing Record 13 of Set 2 | axim
# Processing Record 14 of Set 2 | arvayheer
# Processing Record 15 of Set 2 | yoko
# Processing Record 16 of Set 2 | lively
# Processing Record 17 of Set 2 | anadyr
# Processing Record 18 of Set 2 | al wajh
# Processing Record 19 of Set 2 | port sudan
# Processing Record 20 of Set 2 | smithers
# Processing Record 21 of Set 2 | auki
# Processing Record 22 of Set 2 | salalah
# Processing Record 23 of Set 2 | margaret river
# Processing Record 24 of Set 2 | honcho
# Processing Record 25 of Set 2 | taiohae
# City taiohae not found. Skipping...
# Processing Record 26 of Set 2 | egilsstadir
# Processing Record 27 of Set 2 | yanykurgan
# Processing Record 28 of Set 2 | sitka
# Processing Record 29 of Set 2 | kapa'a
# Processing Record 30 of Set 2 | puerto ayora
# Processing Record 31 of Set 2 
# Processing Record 15 of Set 4 | kodiak
# Processing Record 16 of Set 4 | flying fish cove
# Processing Record 17 of Set 4 | melo
# Processing Record 18 of Set 4 | bonthe
# Processing Record 19 of Set 4 | yeppoon
# Processing Record 20 of Set 4 | nar'yan-mar
# Processing Record 21 of Set 4 | wailua homesteads
# Processing Record 22 of Set 4 | opelousas
# Processing Record 23 of Set 4 | bubaque
# Processing Record 24 of Set 4 | tolanaro
# Processing Record 25 of Set 4 | san antonio
# Processing Record 26 of Set 4 | jalqani
# Processing Record 27 of Set 4 | darwin
# Processing Record 28 of Set 4 | bontang
# Processing Record 29 of Set 4 | were ilu
# Processing Record 30 of Set 4 | ustka
# Processing Record 31 of Set 4 | sheringham
# Processing Record 32 of Set 4 | moranbah
# Processing Record 33 of Set 4 | kununurra
# Processing Record 34 of Set 4 | sanctuary point
# Processing Record 35 of Set 4 | dolores
# Processing Record 36 of Set 4 | yanchep
# Processing Record 37 of Set 4 | badger
# Processing Record 38 of Set 4 | filingue
# Processing Record 39 of Set 4 | gilgit
# Processing Record 40 of Set 4 | northam
# Processing Record 41 of Set 4 | sao joao da barra
# Processing Record 42 of Set 4 | bambanglipuro
# Processing Record 43 of Set 4 | hayma'
# City hayma' not found. Skipping...
# Processing Record 44 of Set 4 | malanje
# Processing Record 45 of Set 4 | tangalle
# Processing Record 46 of Set 4 | puerto san carlos
# City puerto san carlos not found. Skipping...
# Processing Record 47 of Set 4 | labrador city
# Processing Record 48 of Set 4 | uturoa
# Processing Record 49 of Set 4 | mil'kovo
# Processing Record 0 of Set 5 | ilulissat
# Processing Record 1 of Set 5 | ancud
# Processing Record 2 of Set 5 | tadine
# Processing Record 3 of Set 5 | nelson bay
# Processing Record 4 of Set 5 | geraldton
# Processing Record 5 of Set 5 | swakopmund
# Processing Record 6 of Set 5 | chittaranjan
# Processing Record 7 of Set 5 | magadan
# Processing Record 8 of Set 5 | wenling
# Processing Record 9 of Set 5 | sao gabriel da cachoeira
# Processing Record 10 of Set 5 | palanga
# Processing Record 11 of Set 5 | arteche
# Processing Record 12 of Set 5 | evergreen
# Processing Record 13 of Set 5 | carnarvon
# Processing Record 14 of Set 5 | bardai
# Processing Record 15 of Set 5 | nemuro
# Processing Record 16 of Set 5 | carutapera
# Processing Record 17 of Set 5 | punta arenas
# Processing Record 18 of Set 5 | hadibu
# Processing Record 19 of Set 5 | talnakh
# Processing Record 20 of Set 5 | tocopilla
# Processing Record 21 of Set 5 | enewetak
# Processing Record 22 of Set 5 | broome
# Processing Record 23 of Set 5 | cananea
# Processing Record 24 of Set 5 | boonville
# Processing Record 25 of Set 5 | howrah
# Processing Record 26 of Set 5 | palikir - national government center
# Processing Record 27 of Set 5 | kavaratti
# Processing Record 28 of Set 5 | lihue
# Processing Record 29 of Set 5 | springbok
# Processing Record 30 of Set 5 | prado
# Processing Record 31 of Set 5 | sinabang
# Processing Record 32 of Set 5 | essaouira
# Processing Record 33 of Set 5 | manta
# Processing Record 34 of Set 5 | jeddah
# Processing Record 35 of Set 5 | aykhal
# Processing Record 36 of Set 5 | kingston
# Processing Record 37 of Set 5 | isafjordur
# Processing Record 38 of Set 5 | tobi village
# City tobi village not found. Skipping...
# Processing Record 39 of Set 5 | chazuta
# Processing Record 40 of Set 5 | sawa sawa
# Processing Record 41 of Set 5 | fayzabad
# Processing Record 42 of Set 5 | erechim
# Processing Record 43 of Set 5 | puerto rico
# Processing Record 44 of Set 5 | ashland
# Processing Record 45 of Set 5 | luganville
# Processing Record 46 of Set 5 | fraccionamiento los angeles
# City fraccionamiento los angeles not found. Skipping...
# Processing Record 47 of Set 5 | hithadhoo
# Processing Record 48 of Set 5 | fortuna
# Processing Record 49 of Set 5 | troitsko-pechorsk
# Processing Record 0 of Set 6 | belle chasse
# Processing Record 1 of Set 6 | kuchinda
# Processing Record 2 of Set 6 | nadym
# Processing Record 3 of Set 6 | bandarbeyla
# Processing Record 4 of Set 6 | lata
# Processing Record 5 of Set 6 | kapuskasing
# Processing Record 6 of Set 6 | williston
# Processing Record 7 of Set 6 | makokou
# Processing Record 8 of Set 6 | sumbawanga
# Processing Record 9 of Set 6 | pervomayskoye
# Processing Record 10 of Set 6 | nova sintra
# Processing Record 11 of Set 6 | suntar
# Processing Record 12 of Set 6 | hirara
# Processing Record 13 of Set 6 | glace bay
# Processing Record 14 of Set 6 | vilyuchinsk
# Processing Record 15 of Set 6 | zaozersk
# Processing Record 16 of Set 6 | dudinka
# Processing Record 17 of Set 6 | ujae
# Processing Record 18 of Set 6 | rabaul
# Processing Record 19 of Set 6 | nagato
# Processing Record 20 of Set 6 | impfondo
# Processing Record 21 of Set 6 | souillac
# Processing Record 22 of Set 6 | anyama
# Processing Record 23 of Set 6 | greenland
# Processing Record 24 of Set 6 | rio grande
# Processing Record 25 of Set 6 | rio brilhante
# Processing Record 26 of Set 6 | tralee
# Processing Record 27 of Set 6 | rupea
# Processing Record 28 of Set 6 | les avirons
# Processing Record 29 of Set 6 | vorgashor
# Processing Record 30 of Set 6 | houghton
# Processing Record 31 of Set 6 | laguna
# Processing Record 32 of Set 6 | porto novo
# Processing Record 33 of Set 6 | kerouane
# Processing Record 34 of Set 6 | nuku'alofa
# Processing Record 35 of Set 6 | mount gambier
# Processing Record 36 of Set 6 | viqueque
# Processing Record 37 of Set 6 | goldsboro
# Processing Record 38 of Set 6 | pangody
# Processing Record 39 of Set 6 | jining
# Processing Record 40 of Set 6 | tamanrasset
# Processing Record 41 of Set 6 | al ghayzah
# Processing Record 42 of Set 6 | fort st. john
# Processing Record 43 of Set 6 | tondano
# Processing Record 44 of Set 6 | amga
# Processing Record 45 of Set 6 | sao mateus do sul
# Processing Record 46 of Set 6 | mpanda
# Processing Record 47 of Set 6 | orcopampa
# Processing Record 48 of Set 6 | san antonio de pale
# Processing Record 49 of Set 6 | avarua
# Processing Record 0 of Set 7 | shubarshi
# Processing Record 1 of Set 7 | tabou
# Processing Record 2 of Set 7 | shimoda
# Processing Record 3 of Set 7 | fale old settlement
# Processing Record 4 of Set 7 | san luis de la loma
# Processing Record 5 of Set 7 | sinop
# Processing Record 6 of Set 7 | xiongzhou
# Processing Record 7 of Set 7 | porbandar
# Processing Record 8 of Set 7 | baruun-urt
# Processing Record 9 of Set 7 | mina clavero
# Processing Record 10 of Set 7 | afaahiti
# Processing Record 11 of Set 7 | amasra
# Processing Record 12 of Set 7 | emerald
# Processing Record 13 of Set 7 | sanming
# Processing Record 14 of Set 7 | sao paulo de olivenca
# Processing Record 15 of Set 7 | marka
# Processing Record 16 of Set 7 | petropavlovsk-kamchatsky
# Processing Record 17 of Set 7 | serenje
# Processing Record 18 of Set 7 | vereshchagino
# Processing Record 19 of Set 7 | zvishavane
# Processing Record 20 of Set 7 | farah
# Processing Record 21 of Set 7 | trevelin
# Processing Record 22 of Set 7 | sao vicente
# Processing Record 23 of Set 7 | sola
# Processing Record 24 of Set 7 | san bernardo del viento
# Processing Record 25 of Set 7 | taltal
# Processing Record 26 of Set 7 | queenstown
# Processing Record 27 of Set 7 | aginskoye
# Processing Record 2 of Set 9 | dunedin
# Processing Record 3 of Set 9 | iwanai
# Processing Record 4 of Set 9 | taroa
# Processing Record 5 of Set 9 | shakawe
# Processing Record 6 of Set 9 | la passe
# Processing Record 7 of Set 9 | lagos
# Processing Record 8 of Set 9 | monahans
# Processing Record 9 of Set 9 | brisas de zicatela
# Processing Record 10 of Set 9 | borogontsy
# Processing Record 11 of Set 9 | sao jose da coroa grande
# Processing Record 12 of Set 9 | remicourt
# Processing Record 13 of Set 9 | turpan
# Processing Record 14 of Set 9 | yaren
# Processing Record 15 of Set 9 | pelabuhanratu
# Processing Record 16 of Set 9 | alaghsas
# Processing Record 17 of Set 9 | sumberpucung
# Processing Record 18 of Set 9 | al bawiti
# Processing Record 19 of Set 9 | severo-yeniseyskiy
# Processing Record 20 of Set 9 | micheweni
# Processing Record 21 of Set 9 | marsh harbour
# Processing Record 22 of Set 9 | papao
# Processing Record 23 of Set 9 | lazaro cardenas
# Processing Record 24 of Set 9 | sirte
# Processing Record 25 of Set 9 | ta`u
# Processing Record 26 of Set 9 | yinchuan
# Processing Record 27 of Set 9 | langarud
# Processing Record 28 of Set 9 | belyy yar
# Processing Record 29 of Set 9 | palmeira
# Processing Record 30 of Set 9 | cananeia
# Processing Record 31 of Set 9 | saint-joseph
# Processing Record 32 of Set 9 | holualoa
# Processing Record 33 of Set 9 | saint-pierre
# Processing Record 34 of Set 9 | oil city
# Processing Record 35 of Set 9 | nagqu
# Processing Record 36 of Set 9 | santiago de cao
# Processing Record 37 of Set 9 | novaya igirma
# Processing Record 38 of Set 9 | la'ie
# Processing Record 39 of Set 9 | codrington
# Processing Record 40 of Set 9 | aluksne
# Processing Record 41 of Set 9 | umm kaddadah
# Processing Record 42 of Set 9 | vendome
# Processing Record 43 of Set 9 | bac lieu
# Processing Record 44 of Set 9 | alesund
# Processing Record 45 of Set 9 | turabah
# Processing Record 46 of Set 9 | swedru
# Processing Record 47 of Set 9 | ar ruseris
# Processing Record 48 of Set 9 | cabo san lucas
# Processing Record 49 of Set 9 | punta cardon
# Processing Record 0 of Set 10 | pocone
# Processing Record 1 of Set 10 | santa ana
# Processing Record 2 of Set 10 | yung shue wan
# Processing Record 3 of Set 10 | hobyo
# Processing Record 4 of Set 10 | saint-philippe
# Processing Record 5 of Set 10 | harij
# Processing Record 6 of Set 10 | alotau
# Processing Record 7 of Set 10 | mahebourg
# Processing Record 8 of Set 10 | bandar lampung
# Processing Record 9 of Set 10 | kidal
# Processing Record 10 of Set 10 | upper dir
# Processing Record 11 of Set 10 | nimbahera
# Processing Record 12 of Set 10 | zhanaozen
# Processing Record 13 of Set 10 | corner brook
# Processing Record 14 of Set 10 | touros
# Processing Record 15 of Set 10 | bodo
# Processing Record 16 of Set 10 | devinuwara
# City devinuwara not found. Skipping...
# Processing Record 17 of Set 10 | sangkhla buri
# Processing Record 18 of Set 10 | shevchenko
# Processing Record 19 of Set 10 | remire-montjoly
# Processing Record 20 of Set 10 | dobele
# Processing Record 21 of Set 10 | teknaf
# Processing Record 22 of Set 10 | nantucket
# Processing Record 23 of Set 10 | koster
# Processing Record 24 of Set 10 | tommot
# Processing Record 25 of Set 10 | arzamas
# Processing Record 26 of Set 10 | taro
# Processing Record 27 of Set 10 | chibougamau
# Processing Record 28 of Set 10 | namibe
# Processing Record 29 of Set 10 | dambulla
# Processing Record 30 of Set 10 | balabac
# Processing Record 31 of Set 10 | nouadhibou
# Processing Record 32 of Set 10 | limon
# Processing Record 33 of Set 10 | tozkhurmato
# Processing Record 34 of Set 10 | north bend
# Processing Record 35 of Set 10 | yuzhno-kurilsk
# Processing Record 36 of Set 10 | vingt cinq
# City vingt cinq not found. Skipping...
# Processing Record 37 of Set 10 | bitkine
# Processing Record 38 of Set 10 | colonia
# Processing Record 39 of Set 10 | hohhot
# Processing Record 40 of Set 10 | funafuti
# Processing Record 41 of Set 10 | mathba
# Processing Record 42 of Set 10 | mer
# Processing Record 43 of Set 10 | shubarkuduk
# Processing Record 44 of Set 10 | weyburn
# Processing Record 45 of Set 10 | sena madureira
# Processing Record 46 of Set 10 | 'izbat al burj
# City 'izbat al burj not found. Skipping...
# Processing Record 47 of Set 10 | mar del plata
# Processing Record 48 of Set 10 | villa gesell
# Processing Record 49 of Set 10 | brena alta
# Processing Record 0 of Set 11 | tuy hoa
# Processing Record 1 of Set 11 | stettler
# Processing Record 2 of Set 11 | korla
# Processing Record 3 of Set 11 | morehead city
# Processing Record 4 of Set 11 | svetlyy
# Processing Record 5 of Set 11 | menongue
# Processing Record 6 of Set 11 | necocli
# Processing Record 7 of Set 11 | taupo
# Processing Record 8 of Set 11 | illizi
# Processing Record 9 of Set 11 | batticaloa
# Processing Record 10 of Set 11 | dompu
# Processing Record 11 of Set 11 | tromso
# Processing Record 12 of Set 11 | eureka
# Processing Record 13 of Set 11 | petrovsk-zabaykal'skiy
# Processing Record 14 of Set 11 | short pump
# Processing Record 15 of Set 11 | antsiranana
# Processing Record 16 of Set 11 | aras-asan
# Processing Record 17 of Set 11 | usogorsk
# Processing Record 18 of Set 11 | minacu
# City minacu not found. Skipping...
# Processing Record 19 of Set 11 | nizhneudinsk
# Processing Record 20 of Set 11 | hotan
# Processing Record 21 of Set 11 | lepsy
# Processing Record 22 of Set 11 | tranovaho
# City tranovaho not found. Skipping...
# Processing Record 23 of Set 11 | khabarovsk
# Processing Record 24 of Set 11 | crane
# Processing Record 25 of Set 11 | undurkhaan
# Processing Record 26 of Set 11 | lhasa
# Processing Record 27 of Set 11 | ierapetra
# Processing Record 28 of Set 11 | sinan
# Processing Record 29 of Set 11 | ondjiva
# Processing Record 30 of Set 11 | iquique
# Processing Record 31 of Set 11 | inyonga
# Processing Record 32 of Set 11 | serowe
# Processing Record 33 of Set 11 | saudarkrokur
# Processing Record 34 of Set 11 | general pico
# Processing Record 35 of Set 11 | wellington
# Processing Record 36 of Set 11 | cadale
# Processing Record 37 of Set 11 | jinka
# Processing Record 38 of Set 11 | tarazona
# Processing Record 39 of Set 11 | kaa-khem
# Processing Record 40 of Set 11 | juterbog
# Processing Record 41 of Set 11 | yevpatoriya
# Processing Record 42 of Set 11 | pontianak
# Processing Record 43 of Set 11 | arno
# Processing Record 44 of Set 11 | rabo de peixe
# Processing Record 45 of Set 11 | sao miguel
# Processing Record 46 of Set 11 | beteza
# City beteza not found. Skipping...
# Processing Record 47 of Set 11 | kokofata
# City kokofata not found. Skipping...
# Processing Record 48 of Set 11 | taulaga
# Processing Record 49 of Set 11 | dem'yanovo
# Processing Record 0 of Set 12 | hammerfest
# Processing Record 1 of Set 12 | carazinho
# Processing Record 2 of Set 12 | ciudad lazaro cardenas
# Processing Record 3 of Set 12 | lamu
# Processing Record 4 of Set 12 | tharangambadi
# Processing Record 5 of Set 12 | qamdo
# Processing Record 6 of Set 12 | balboa
# Processing Record 7 of Set 12 | neiafu
# Processing Record 8 of Set 12 | southport
# Processing Record 9 of Set 12 | mukharram al fawqani
# Processing Record 10 of Set 12 | campbell river
# Processing Record 11 of Set 12 | guliston
# Processing Record 12 of Set 12 | pontes e lacerda
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          545
# Lat           545
# Lng           545
# Max Temp      545
# Humidity      545
# Cloudiness    545
# Wind Speed    545
# Country       545
# Date          545
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                lompoc  34.6391 -120.4579     14.27        88          40
# 1            gadzhiyevo  69.2551   33.3362     -7.20        85           3
# 2  nikolayevsk-on-amure  53.1406  140.7300     -1.84        93         100
# 3              bilibino  68.0546  166.4372    -29.12        94          17
# 4      puerto leguizamo  -0.1934  -74.7819     22.87        97          98
#
#    Wind Speed Country        Date
# 0        0.45      US  1732683700
# 1        6.73      RU  1732683704
# 2        6.29      RU  1732683706
# 3        1.77      RU  1732683708
# 4        0.65      CO  1732683709

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                          City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                      lompoc  34.6391 -120.4579     14.27        88
# 1                  gadzhiyevo  69.2551   33.3362     -7.20        85
# 2        nikolayevsk-on-amure  53.1406  140.7300     -1.84        93
# 3                    bilibino  68.0546  166.4372    -29.12        94
# 4            puerto leguizamo  -0.1934  -74.7819     22.87        97
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                40        0.45      US  1732683700
# 1                 3        6.73      RU  1732683704
# 2               100        6.29      RU  1732683706
# 3                17        1.77      RU  1732683708
# 4                98        0.65      CO  1732683709

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lng'],city_data_df['Lat'],c=city_data_df['Max Temp'])
clb = plt.colorbar()

# Incorporate the other graph properties
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("Latitude vs. Temperature (2024-06-17)")
clb.set_label("Max Temperature")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lng'],city_data_df['Lat'],c=city_data_df['Humidity'])
clb = plt.colorbar()
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("Latitude vs. Humidity (2024-06-17)")
clb.set_label("Humidity (%)")


# Incorporate the other graph properties
plt.savefig("output_data/Fig2.png")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lng'],city_data_df['Lat'],c=city_data_df['Cloudiness'])
clb = plt.colorbar()
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("City Max Latitude vs. Cloudiness (2024-06-17)")
clb.set_label("Cloudiness (%)")

# Incorporate the other graph properties
plt.savefig("output_data/Fig3.png")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lng'],city_data_df['Lat'],c=city_data_df['Wind Speed'])
clb = plt.colorbar()
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("Latitude vs. Wind Speed (2024-06-17)")
clb.set_label("Wind Speed (m/s)")

# Incorporate the other graph properties
plt.savefig("output_data/Fig4.png")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_lin_regression(x, y, xlabel, ylabel, title, hemisphere, save_fig=False):
    # Linear regression variables
    slope, intercept, rvalue, pvalue, stderr = linregress(x, y)

   # Regression line calculation
    regress_values = x * slope + intercept
    line_eq = f"y = {slope:.2f}x + {intercept:.2f}\nR² = {rvalue**2:.2f}"
    
    # Create scatter plot
    plt.scatter(x, y)
    plt.plot(x, regress_values, "r-", label="Regression Line")
    
    # Annotate the plot with regression equation and R² value
    plt.annotate(line_eq, (min(x), min(y)), fontsize=12, color="red", ha="left", va="bottom")
    
    # Add labels and title
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(f"{hemisphere} Hemisphere: {title}")
    
    # Display legend
    plt.legend()
    
    # Save the figure if specified
    if save_fig:
        plt.savefig(f"output_data/{title.replace(' ', '_')}_LinearRegression.png")
    
    # Show plot
    plt.show()
    
    print(f'The r^2-value is: {rvalue**2:.4f}')

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df= city_data_df[city_data_df['Lat']>=0]

# Display sample data
northern_hemi_df.head()
# Out:
#                          City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                      lompoc  34.6391 -120.4579     14.27        88
# 1                  gadzhiyevo  69.2551   33.3362     -7.20        85
# 2        nikolayevsk-on-amure  53.1406  140.7300     -1.84        93
# 3                    bilibino  68.0546  166.4372    -29.12        94
# 5                   jamestown  42.0970  -79.2353      2.79        80
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                40        0.45      US  1732683700
# 1                 3        6.73      RU  1732683704
# 2               100        6.29      RU  1732683706
# 3                17        1.77      RU  1732683708
# 5               100        6.69      US  1732683507

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat']< 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 4        puerto leguizamo  -0.1934  -74.7819     22.87        97          98
# 6            port douglas -16.4833  145.4667     28.34        70          70
# 8           alice springs -23.7000  133.8833     30.75        37          99
# 9                 ushuaia -54.8000  -68.3000      5.81        70           0
# 13          port mathurin -19.6833   63.4167     24.33        79          24
#
#          Wind Speed Country        Date
# City_ID
# 4              0.65      CO  1732683709
# 6              4.48      AU  1732683713
# 8              3.60      AU  1732683716
# 9              8.75      AR  1732683603
# 13            10.05      MU  1732683725

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
plot_lin_regression(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'], "Latitude", "Max Temperature", "Latitude vs. Temperature", "Northern", save_fig=True)
# Out:
# The r^2-value is: 0.7500

# %%
# Linear regression on Southern Hemisphere
plot_lin_regression(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'], "Latitude", "Max Temperature", "Latitude vs. Temperature", "Southern", save_fig=True)
# Out:
# The r^2-value is: 0.3910

# %% [markdown]
# **Discussion about the linear relationship:** There is a stronger correlation between latitude and temperature in the Northern Hemisphere with a R-sq closer to 1. On the other hand the correlation between this two factors in the Southern Hemisphere is weak with a R-sq closer to 0.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_lin_regression(northern_hemi_df['Lat'], northern_hemi_df['Humidity'], "Latitude", "Humidity (%)", "Latitude vs. Humidity", "Northern", save_fig=True)
# Out:
# The r^2-value is: 0.0696

# %%
# Southern Hemisphere
plot_lin_regression(southern_hemi_df['Lat'], southern_hemi_df['Humidity'], "Latitude", "Humidity (%)", "Latitude vs. Humidity", "Southern", save_fig=True)
# Out:
# The r^2-value is: 0.0051

# %% [markdown]
# **Discussion about the linear relationship:**  There is no correlation between latitude and humidity since R squared values are near to 0.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_lin_regression(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'], "Latitude", "Cloudiness (%)", "Latitude vs. Cloudiness", "Northern", save_fig=True)
# Out:
# The r^2-value is: 0.0147

# %%
# Southern Hemisphere
plot_lin_regression(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'], "Latitude", "Cloudiness (%)", "Latitude vs. Cloudiness", "Southern", save_fig=True)
# Out:
# The r^2-value is: 0.0542

# %% [markdown]
# **Discussion about the linear relationship:** There is no correlation between latitude and Cloudiness since R squared values are near to 0.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_lin_regression(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'], "Latitude", "Wind Speed (m/s)", "Latitude vs. Wind Speed", "Northern", save_fig=True)
# Out:
# The r^2-value is: 0.0060

# %%
# Southern Hemisphere
plot_lin_regression(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'], "Latitude", "Wind Speed (m/s)", "Latitude vs. Wind Speed", "Southern", save_fig=True)
# Out:
# The r^2-value is: 0.0357

# %% [markdown]
# **Discussion about the linear relationship:** There is no correlation between latitude and Cloudiness since R squared values are near to 0.
